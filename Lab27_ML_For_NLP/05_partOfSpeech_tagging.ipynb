# %% [markdown]
# ### how to find part of speech

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tag import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\HashanEranga\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HashanEranga\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HashanEranga\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus = """The quick brown fox jumps over the lazy dog.",
    "She sells sea shells by the sea shore.",
    "How much wood would a woodchuck chuck, if a woodchuck could chuck wood?
"""

# %%
lemmatizer = WordNetLemmatizer()
english_stop_words = set(stopwords.words('english'))

# %%
sentences = sent_tokenize(corpus)
print(sentences)
# Out:
# ['The quick brown fox jumps over the lazy dog.', '",\n    "She sells sea shells by the sea shore.', '",\n    "How much wood would a woodchuck chuck, if a woodchuck could chuck wood?']

# %%
def get_wordnet_pos(word):
    """Map POS tag to the first character lemmatize () accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# %%
def lemmatize_sentence(sentence):
    """Lemmatizes the given sentence"""
    words = nltk.word_tokenize(sentence)
    lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in words if word not in english_stop_words]
    return ' '.join(lemmatized_words)

# %%
for sentence in sentences:
    lemmatized_sentence = lemmatize_sentence(sentence)
    print("Original sentence:", sentence)
    print("Lemmatized sentence:", lemmatized_sentence)
    print("")
# Out:
# Original sentence: The quick brown fox jumps over the lazy dog.
# Lemmatized sentence: The quick brown fox jump lazy dog .
#
# Original sentence: ",
#     "She sells sea shells by the sea shore.
# Lemmatized sentence: `` , `` She sell sea shell sea shore .
#
# Original sentence: ",
#     "How much wood would a woodchuck chuck, if a woodchuck could chuck wood?
# Lemmatized sentence: `` , `` How much wood would woodchuck chuck , woodchuck could chuck wood ?
