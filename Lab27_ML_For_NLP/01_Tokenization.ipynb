# %% [markdown]
# ### Tokenization

# %%
from nltk import wordpunct_tokenize
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\hashaneranga\documents\projects\machinelearning_and_datamining_fundamentals\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\hashaneranga\documents\projects\machinelearning_and_datamining_fundamentals\.venv\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\hashaneranga\documents\projects\machinelearning_and_datamining_fundamentals\.venv\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hashaneranga\documents\projects\machinelearning_and_datamining_fundamentals\.venv\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in c:\users\hashaneranga\documents\projects\machinelearning_and_datamining_fundamentals\.venv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\hashaneranga\documents\projects\machinelearning_and_datamining_fundamentals\.venv\lib\site-packages (from click->nltk) (0.4.6)

# %%
from nltk.tokenize import sent_tokenize, word_tokenize, wordpunct_tokenize

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HashanEranga\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
corpus = """
    Hello, This is sentence 1. This is sentence 2. This is sentence 3. This is sentence 4. This isn't sentence 5.
"""

# %%
sent_tokenize(corpus)
# Out:
# ['\n    Hello, This is sentence 1.',
#  'This is sentence 2.',
#  'This is sentence 3.',
#  'This is sentence 4.',
#  "This isn't sentence 5."]

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'This',
#  'is',
#  'sentence',
#  '1',
#  '.',
#  'This',
#  'is',
#  'sentence',
#  '2',
#  '.',
#  'This',
#  'is',
#  'sentence',
#  '3',
#  '.',
#  'This',
#  'is',
#  'sentence',
#  '4',
#  '.',
#  'This',
#  'is',
#  "n't",
#  'sentence',
#  '5',
#  '.']

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'This',
#  'is',
#  'sentence',
#  '1',
#  '.',
#  'This',
#  'is',
#  'sentence',
#  '2',
#  '.',
#  'This',
#  'is',
#  'sentence',
#  '3',
#  '.',
#  'This',
#  'is',
#  'sentence',
#  '4',
#  '.',
#  'This',
#  'isn',
#  "'",
#  't',
#  'sentence',
#  '5',
#  '.']
